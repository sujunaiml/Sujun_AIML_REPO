# %%
# %matplotlib inline
from IPython.display import HTML
from numpy import *
import matplotlib.pyplot as plt
import pandas as pd
import os
variable = pd.read_csv(r"D:\AIMT_INSTALL_SOFTWARE\envs\DataScience_AIML\DatasciencewithAIML\data.csv")
variable.head() 
data = genfromtxt('D:\AIMT_INSTALL_SOFTWARE\envs\DataScience_AIML\DatasciencewithAIML\data.csv', delimiter=',')

#Extract columns
x = array(data[:,0])
y = array(data[:,1])

#Plot the dataset
plt.scatter(x,y)
plt.xlabel('Hours of study')
plt.ylabel('Test scores')
plt.title('Dataset')
plt.show()
